# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good) Exercises</span></div>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# The code shown in the Code tab generates the ‘Before’ figure shown in the Plots tab. <br>
# Your task is to modify this code to end with the ‘After’ figure in ``jpg`` format.<br>
# Here are some things to get you started: <br>
#
# 1. Remove the text ‘I am..’
# 2. Change the colours used for filling.
# 3. Change the limits of the filled areas.
# 4. Add titles to each subplot.
# 5. Share the x axis across columns.
# 6. Add/Remove labels to the x-axis.
# 7. Make the tick labels of the two bottom plots the same.
# 8. Add grids to all subplots.
# 9. Add a legend to all subplots in the upper right position.
# 10. Use ``tight_layout()`` to improve the figure.
# 11. Save the figure as a ``jpg`` file.

# %% [markdown]
# Before: ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_good_exercise-01_problem.png)
# After: ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_good_exercise-01_solution.png)

# %%
import numpy as np
from matplotlib import pyplot as plt
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharex='col', sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1.25, color=(1.0, 0.5, 0.5), alpha=.25)
axes[0, 0].set_xlabel('')
axes[0, 0].legend(loc='upper right', frameon=True)
axes[0, 0].set_xlim(-np.pi, np.pi) #Limit x-axis
axes[0, 0].set_ylim(-1.25, 1.25) #Limit y-axis
axes[0, 0].legend(loc='upper right', frameon=True) #Add legend with border

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -1.25, color='green', alpha=.125) #Change this
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='upper right', frameon=True) #Changed Legend format.
axes[0, 1].set_xlim(-np.pi, np.pi) #Limit x-axis
axes[0, 1].set_ylim(-1.25, 1.25) #Limit y-axis
axes[0, 1].set_title('$\sin x$ & $\sin^2x$') #add title

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$\sin 2x$')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125) #add -25 to specify y2 coordinate so will fill all the way till there.
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend(loc='upper right', frameon=True)
axes[1, 0].set_ylim(-27, 14)


#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x,-25, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 1].legend(loc='upper right', frameon=True)
axes[1, 1].set_xlabel('Angle (radians)')


# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

# plt.tight_layout()
plt.show(block=False)

# %%
#Extra stuff that can be done


import numpy as np
from matplotlib import pyplot as plt
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharex='col', sharey='row')


#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1.25, color=(1.0, 0.5, 0.5), alpha=.25)
axes[0, 0].set_xlabel('')
axes[0, 0].legend(loc='upper right', frameon=True)
axes[0, 0].set_xlim(-np.pi, np.pi) #Limit x-axis
axes[0, 0].set_ylim(-1.25, 1.25) #Limit y-axis
axes[0, 0].legend(loc='upper right', frameon=True) #Add legend with border


# Add a secondary y-axis to subplot 1
ax_sec = axes[0, 0].twinx()
ax_sec.set_ylabel('Alternative Scale')


# Plot using a colormap for subplot 1
sc = axes[0, 0].scatter(x, sin_x, c=x, cmap='viridis')
fig.colorbar(sc, ax=axes[0, 1], label='X values')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -1.25, color='green', alpha=.125) #Change this
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='upper right', frameon=True) #Changed Legend format.
axes[0, 1].set_xlim(-np.pi, np.pi) #Limit x-axis
axes[0, 1].set_ylim(-1.25, 1.25) #Limit y-axis
axes[0, 1].set_title('$\sin x$ & $\sin^2x$') #add title

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$\sin 2x$')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125) #add -25 to specify y2 coordinate so will fill all the way till there.
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend(loc='upper right', frameon=True)
axes[1, 0].set_ylim(-27, 14)


#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x,-25, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 1].legend(loc='upper right', frameon=True)
axes[1, 1].set_xlabel('Angle (radians)')


# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

# plt.tight_layout()
plt.show(block=False)

#Save figure as jpg file
plt.savefig('plot_good.jpg', dpi=300)
