# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # A simple plot

# %% [markdown]
# ## Let’s look at some code.

# %%
from matplotlib import pyplot as plt  # Importing the pyplot module from matplotlib and aliasing it as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]  # X-values for the data points
y_1 = [0, 2, 4, 6, 8, 10, 12]  # Y-values for the first set of data points
y_2 = [0, 3, 6, 9, 12, 15, 18]  # Y-values for the second set of data points

# Let's start plotting
plt.plot(x, y_1, label='Y values', color='red', linestyle='dashed')  # Plotting the first set of data points with a red dashed line
plt.xlabel('x-values')  # Labeling the x-axis
plt.ylabel('y-values')  # Labeling the y-axis
plt.title('X vs Y')  # Setting the title of the plot
plt.grid(alpha=0.8)  # Adding a grid to the plot with 80% transparency
plt.legend(loc='upper left')  # Adding a legend to the plot in the bottom-left corner

# %% [markdown]
# ### Extra?

# %%
from matplotlib import pyplot as plt  # Importing the pyplot module from matplotlib and aliasing it as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]  # X-values for the data points
y_1 = [0, 2, 4, 6, 8, 10, 12]  # Y-values for the first set of data points
y_2 = [0, 3, 6, 9, 12, 15, 18]  # Y-values for the second set of data points

# Let's start plotting
plt.plot(x, y_1, label='Line 1', color='red', linestyle='dashed', linewidth=2, marker='o', markersize=8)  # Plotting the first set of data points with a red dashed line, circles as markers, and customized linewidth and markersize
plt.plot(x, y_2, label='Line 2', color='blue', linestyle='solid', linewidth=2, marker='s', markersize=8)  # Plotting the second set of data points with a blue solid line, squares as markers, and customized linewidth and markersize
plt.xlabel('x-values')  # Labeling the x-axis
plt.ylabel('y-values')  # Labeling the y-axis
plt.title('X vs Y')  # Setting the title of the plot
plt.grid(alpha=0.8, linestyle='--')  # Adding a grid to the plot with 80% transparency and dashed lines
plt.legend(loc='upper left', fontsize='large')  # Adding a legend to the plot in the upper left corner with larger font size
plt.text(4, 5, 'Text Annotation', fontsize=12, color='green')  # Adding a text annotation at position (3, 10) with a custom font size and color
plt.axhline(y=8, color='gray', linestyle=':')  # Adding a horizontal line at y=8 with a gray color and dotted linestyle
plt.xlim(0, 7)  # Setting the x-axis limits from 0 to 7
plt.ylim(0, 20)  # Setting the y-axis limits from 0 to 20
plt.savefig('plot.png', dpi=300)  # Saving the plot as a PNG image file with a resolution of 300 dpi
plt.show()  # Displaying the plot

# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.4 kB 326.8 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 262.6 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 262.6 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 178.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
# ...

# %%
import numpy as np
import scipy
from scipy.stats import linregress
from matplotlib import pyplot as plt

# Some data for plotting
x = np.array([0, 1, 2, 3, 4, 5, 6])
y = np.array([0, 2, 4, 6, 8, 10, 12])

# Fit a linear regression line to the data
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Derive the equation of the regression line
equation = f'y = {slope:.2f}x + {intercept:.2f}'

# Plot the data points and the regression line
plt.plot(x, y, 'o', label='Data points')
plt.plot(x, slope * x + intercept, 'r-', label='Regression line')

# Annotate the equation on the graph
plt.text(3, 9, equation, fontsize=12)

# Add labels, title, grid, and legend
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y with Regression Line')
plt.grid(alpha=0.8)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Things to note

# %% [markdown]
# | Long form | Abbreviation |
# |:---------:|:------------:|
# |   color   |       c      |
# | linestyle |      ls      |
# | linewidth |      lw      |
#
# <br>
# 1. Can use following abbreviations:

# %%
plt.plot(x, y, color='red', linestyle='dashed', linewidth=2) #Same output
plt.plot(x, y, c='red', ls='dashed', lw=2)

# %% [markdown]
# 2. Jupyter is an interactive environment, so you will see an output even if you omit plt.show(). However, it is good practice to include this line anyway so your code will also work in non-interactive environments (for instance, when the script is run directly from the command line).

# %% [markdown]
# 3. The plotting functions usually have default values for the styling parameters. So, if you wish, you can keep it simple and plot just using:

# %%
plt.plot(x, y_1, y_2)

# %% [markdown]
# 4. You can split the arguments into separate lines to improve readability. <br>
# So, both of the following forms are acceptable.

# %%
plt.plot(x, y_1, label='Y values',
           color='red', linestyle='dashed')
#Or plt.plot(x, y, color='red', linestyle='dashed', linewidth=2)
#Both acceptable.

# %% [markdown]
# ## Adding another plot

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.plot(x, y_2,label='Y2 values', color='blue')               #Add this to plot another line.

# %% [markdown]
# ## Yet another plot but with error bars

# %%
#Include x and y error bars for the points using errorbar(). 
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.errorbar(x, y_3,
             xerr=x_error, yerr=y_error,
             label="Y3 with errors",
             color="green")
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Better with NumPy

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x) #Convert Python lists into NumPy arrays. 
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ##  Adding mathematical functions

# %%
# Note: NumPy arrays allow us to generate data-related mathematical functions.
# Example here which plots x^2 and sin(x).
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
#Have another y-axis that shares the same x-axis using command twinx().
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Create an array of values from 0 to 6 using np.linspace()
x = np.linspace(0, 6, 100)  # Generates 100 evenly spaced values between 0 and 6

# Calculate the square of each value in x
x2 = x**2

# Calculate the sine of each value in x
sin_x = np.sin(x)

# Plot x vs. x^2 with a red dashed line, and label it as 'x^2'
plt.plot(x, x2, label='x^2', color='red', linestyle='dashed')

# Add a legend to the plot and position it in the lower left corner
plt.legend(loc='lower left')

# Create a new y-axis for the plots that come after
plt.twinx()

# Plot x vs. sin(x) with a blue line, and label it as 'sin(x)'
plt.plot(x, sin_x, label='sin(x)', color='blue')

# Add a legend to the plot and position it in the lower right corner
plt.legend(loc='lower right')

# %% [markdown]
# ### Things to note

# %% [markdown]
# - We now have two ``legend()`` calls, one for each axis.
#
# - Our plot still does not look good because we have only a few points. Let’s use ``np.linspace`` to fix this with: <br>
# x = np.linspace(0, 6, 100)

# %% [markdown]
# # Saving to disc

# %% [markdown]
# If you want to use your plot in a report or presentation, you must first save it to disk. Luckily, Matplotlib makes it astonishingly easy to export plots into many formats (PDF, JPEG, PNG, BMP, etc.) and at different resolutions.
# <br>
# - We need to use the function ``savefig()`` for this.
# - We specify the format with the extension (e.g., ``filename.pdf``) of the file name,
# - We specify resolution by use dots-per-inch (``dpi``).
#
# <br>
# Note: If I had wanted the plot saved in JPEG format, I would have used simple-plot.jpeg. Further, I would increase dpi if I wanted a higher resolution. <br>
# When you run this code, you will find the file saved in the same directory (folder) as the one in your notebook lives in. If you want it saved elsewhere, specify the path in more detail. For example: <br>

# %%
plt.savefig('C://Desktop/simple-plot.png', dpi=150)

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# By default, when you specify a filename for plt.savefig(), it saves the file in the current working directory, which is typically the directory where your Jupyter Notebook or Python script is located. If you want to save the file in a different directory, you can provide the full path to the desired location instead of just the filename. For example:
# plt.savefig(r'C:\Users\teren\OneDrive\Desktop\simple-plot.png', dpi=150)

# %% [markdown]
# # A real example: Global Warming

# %% [markdown]
# ## Plotting data from files

# %% [markdown]
# Plotting data stored in a file (e.g., spreadsheet, text file, database) is a routine task for a scientist. In fact, the first thing you should do with any data is to look at it with a simple plot.
#
# For the rest of this section, I will use the Earth’s land temperature data from the [Berkeley Earth website](https://berkeleyearth.org/). Please visit the site (Global Warming --> Data Overview) and download the average temperature data for Daily Land. The original name of the file should be ``Complete_TAVG_daily.txt``

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5) #used a small alpha value to soften the colour of the plot and made the plot range symmetrical in the y direction.
plt.ylim([-8, 8])

#hlines() function needs a y-value and starting and ending values for x. 
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey') #add a horizontal line at the zero value to highlight the trend shown by the data.

# %% [markdown]
# ## Styles

# %% [markdown]
# Most people want a decent-looking plot without spending time customising it. To facilitate this Matplotlib offers some standard style templates (see [here](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html)). I am going to use the one called **fivethirtyeight**.

# %%
import numpy as np
# Set the plot style to 'fivethirtyeight'
plt.style.use('fivethirtyeight')

# Load data from the file 'Complete_TAVG_daily.txt', skipping the first 24 rows
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

# Extract the date column from the data
date = data[:, 0]

# Extract the temperature anomaly column from the data
anomaly = data[:, -1]

# Plot the date against the temperature anomaly with transparency set to 0.5
plt.plot(date, anomaly, alpha=.5)

# Add a horizontal dashed line at y=0 to indicate the average temperature
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# Set the y-axis limits to -8 and 8
plt.ylim([-8, 8])

# Label the x-axis as 'Date'
plt.xlabel('Date')

# Label the y-axis as 'Temperature Anomaly'
plt.ylabel('Temperature Anomaly')

# Set the title of the plot as 'Temperature anomaly (Relative to average from Jan 1951 - Dec 1980.)'
plt.title('Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly\n(Relative to average from Jan 1951 - Dec 1980.)')

# %% [markdown]
# ### xkcd!

# %% [markdown]
# Since we are talking about styles, I must tell you that the developers of Matplotlib have a healthy sense of humour and have included the option of making your plots in the xkcd style. To enable this, just run ``plt.xkcd()`` instead of setting a style. Here is what the previous plot looks like using the xkcd style.

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.xkcd()
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

#This style uses specific font family 'xkcd', 'xkcd script' and 'Comic Neue' but I'm not going to manually download and use fonts so ...
# Specify a different font family
plt.rcParams['font.family'] = 'Arial'  # You can replace the style font with any font available in the system eg. 'Arial' 

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')

# %% [markdown]
# ### Resetting styles

# %%
#If you want to reset things and jump out of this style, you need to set the default style using:
plt.style.use('default')
